# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset
df=pd.read_csv('Heart_Disease_Prediction.csv')
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.shape
# Out:
# (270, 14)

# %%
# Convert 'Heart Disease' column to binary
df['Heart Disease'] = df['Heart Disease'].map({'Presence': 1, 'Absence': 0})

# Convert categorical columns using one-hot encoding
categorical_cols = ['Heart Disease']
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
X = df.drop('Heart Disease', axis=1)
y = df['Heart Disease']

# %%
X
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    1
# Name: Heart Disease, Length: 270, dtype: int64

# %%
summary_stats = df.describe().T
summary_stats['range'] = summary_stats['max'] - summary_stats['min']
summary_stats = summary_stats[['mean', '50%', 'std', 'min', 'max', 'range']]
summary_stats.columns = ['Mean', 'Median', 'Standard Deviation', 'Min', 'Max', 'Range']

# %%
print(summary_stats)
# Out:
#                                Mean  Median  Standard Deviation    Min    Max  \
# Age                       54.433333    55.0            9.109067   29.0   77.0
# Sex                        0.677778     1.0            0.468195    0.0    1.0
# Chest pain type            3.174074     3.0            0.950090    1.0    4.0
# BP                       131.344444   130.0           17.861608   94.0  200.0
# Cholesterol              249.659259   245.0           51.686237  126.0  564.0
# FBS over 120               0.148148     0.0            0.355906    0.0    1.0
# EKG results                1.022222     2.0            0.997891    0.0    2.0
# Max HR                   149.677778   153.5           23.165717   71.0  202.0
# Exercise angina            0.329630     0.0            0.470952    0.0    1.0
# ST depression              1.050000     0.8            1.145210    0.0    6.2
# Slope of ST                1.585185     2.0            0.614390    1.0    3.0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 198   69    0                1  140          239             0            0
# 78    42    0                3  120          209             0            0
# 218   54    1                3  120          258             0            2
# 257   55    1                4  132          353             0            0
# 42    44    1                3  130          233             0            0
# ..   ...  ...              ...  ...          ...           ...          ...
# 135   46    0                3  142          177             0            2
# 118   66    0                1  150          226             0            0
# 23    47    1                4  112          204             0            0
# 86    62    1                2  128          208             1            2
# 113   54    0                3  135          304             1            0
#
# ...

# %%
y_train #heart disease
# Out:
# 198    0
# 78     0
# 218    0
# 257    1
# 42     0
#       ..
# 135    0
# 118    0
# 23     0
# 86     0
# 113    0
# Name: Heart Disease, Length: 216, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
X_train=ss.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.5816619 , -1.33012434, -2.24706983, ..., -0.94942533,
#          1.38913295, -0.85704115],
#        [-1.43674523, -1.33012434, -0.15045176, ...,  0.65272991,
#         -0.74647358, -0.85704115],
#        [-0.09523095,  0.75180941, -0.15045176, ...,  0.65272991,
#         -0.74647358,  1.20558713],
#        ...,
#        [-0.87778095,  0.75180941,  0.89785727, ..., -0.94942533,
#         -0.74647358, -0.85704115],
#        [ 0.7991119 ,  0.75180941, -1.19876079, ..., -0.94942533,
#         -0.74647358, -0.85704115],
#        [-0.09523095, -1.33012434, -0.15045176, ..., -0.94942533,
#         -0.74647358, -0.85704115]])

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# Select a single feature (e.g., 'BP')
X = df[['Cholesterol']]
y = LabelEncoder().fit_transform(df['Heart Disease'])

# Fit logistic regression model
model = LogisticRegression()
model.fit(X, y)

# Create a range of values for 'BP' to plot the sigmoid curve
X_test = np.linspace(X.min(), X.max(), 300).reshape(-1, 1)

# Predict probabilities using the logistic regression model
y_prob = model.predict_proba(X_test)[:, 1]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(X_test, y_prob, color='red', label='Sigmoid Curve')
plt.scatter(X, y, color='blue', edgecolor='k', label='Data Points')
plt.xlabel('Cholesterol')
plt.ylabel('Probability of Heart Disease Presence')
plt.title('Logistic Regression using Sigmoid Function')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(random_state=42)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Get feature importances
importances = model.feature_importances_
features = X.columns

# Plotting the feature importances
plt.figure(figsize=(10, 8))
plt.barh(features, importances, color='blue')
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance in Random Forest')
plt.show()

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(probability=True, random_state=42)

# %%
svm_model.fit(X_train, y_train)
# Out:
# SVC(probability=True, random_state=42)

# %%
y_pred = svm_model.predict(X_test)
y_pred_proba = svm_model.predict_proba(X_test)[:, 1]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.preprocessing import LabelEncoder

# Select two features (e.g., 'BP' and 'Cholesterol')
X = df[['BP', 'Cholesterol']]
y = LabelEncoder().fit_transform(df['Heart Disease'])

# Fit the SVM model
model = svm.SVC(kernel='linear')
model.fit(X, y)

# Create a mesh grid to plot the decision boundary
x_min, x_max = X['BP'].min() - 10, X['BP'].max() + 10
y_min, y_max = X['Cholesterol'].min() - 10, X['Cholesterol'].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Predict classifications across the grid
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary
plt.contourf(xx, yy, Z, alpha=0.4, cmap=plt.cm.coolwarm)

# Plot the original data points
plt.scatter(X['BP'], X['Cholesterol'], c=y, s=30, cmap=plt.cm.coolwarm, edgecolors='k')

# Plot the support vectors
plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
            facecolors='none', edgecolors='k', label='Support Vectors')

# Labels and title
plt.xlabel('Blood Pressure (BP)')
plt.ylabel('Cholesterol')
plt.title('SVM Decision Boundary with Support Vectors')
plt.legend()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.preprocessing import LabelEncoder

# Select two features (e.g., 'BP' and 'Cholesterol')
X = df[['BP', 'Cholesterol']]
y = LabelEncoder().fit_transform(df['Heart Disease'])

# Fit the SVM model
model = svm.SVC(kernel='linear')
model.fit(X, y)

# Create a mesh grid to plot the decision boundary
x_min, x_max = X['BP'].min() - 10, X['BP'].max() + 10
y_min, y_max = X['Cholesterol'].min() - 10, X['Cholesterol'].max() + 10
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Predict classifications across the grid
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot the decision boundary
plt.contourf(xx, yy, Z, alpha=0.4, cmap=plt.cm.coolwarm)

# Plot the original data points
plt.scatter(X['BP'], X['Cholesterol'], c=y, s=30, cmap=plt.cm.coolwarm, edgecolors='k')

# Plot the support vectors
plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
            facecolors='none', edgecolors='k', label='Support Vectors')

# Labels and title
plt.xlabel('Blood Pressure (BP)')
plt.ylabel('Cholesterol')
plt.title('SVM Decision Boundary with Support Vectors')
plt.legend()
plt.show()

# %%
neigh = KNeighborsClassifier(n_neighbors=3)

# %%
neigh.fit(X_train, y_train)

# %%
y_predict=neigh.predict(X_test)

# %%
y_predict

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
dt_model = DecisionTreeClassifier(random_state=42)

# Train the model
dt_model.fit(X_train, y_train)

# Make predictions
y_pred = dt_model.predict(X_test)
y_pred_proba = dt_model.predict_proba(X_test)[:, 1]

# %%
plt.figure(figsize=(20, 10))
plot_tree(dt_model, feature_names=X.columns, class_names=['Absence', 'Presence'], filled=True)
plt.title('Decision Tree Structure')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)

# %%
# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

# %%
# Print metrics
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"ROC-AUC: {roc_auc:.2f}")

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Absence', 'Presence'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix - Decision Tree')
plt.show()

# %%
#Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='Max HR', hue='Heart Disease')
plt.title('Scatter Plot of Age vs. Max HR')
plt.show()

# %%
report = classification_report(y_test, y_pred, target_names=['Absence', 'Presence'])

# Print the classification report
print("Classification Report")
print(report)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      Absence       0.00      0.00      0.00        36
#     Presence       0.33      1.00      0.50        18
#
#     accuracy                           0.33        54
#    macro avg       0.17      0.50      0.25        54
# weighted avg       0.11      0.33      0.17        54

# %%
heart_disease_counts = df['Heart Disease'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
heart_disease_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.title('Heart Disease Distribution')
plt.ylabel('')  # Hide y-label
plt.show()
